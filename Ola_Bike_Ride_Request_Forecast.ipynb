# %% [markdown]
# <a href="https://colab.research.google.com/github/itsnikhil-96/js/blob/main/ML_PROJECT_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Importing dataset

# %%
data = pd.read_csv("/content/drive/MyDrive/csv sem 4/train (1).csv")

# %% [markdown]
# Printing dataset

# %%
data
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 0      01-01-2011 00:00       1        0           0        1   9.84  14.395
# 1      01-01-2011 01:00       1        0           0        1   9.02  13.635
# 2      01-01-2011 02:00       1        0           0        1   9.02  13.635
# 3      01-01-2011 03:00       1        0           0        1   9.84  14.395
# 4      01-01-2011 04:00       1        0           0        1   9.84  14.395
# ...                 ...     ...      ...         ...      ...    ...     ...
# 10881  19-12-2012 19:00       4        0           1        1  15.58  19.695
# 10882  19-12-2012 20:00       4        0           1        1  14.76  17.425
# 10883  19-12-2012 21:00       4        0           1        1  13.94  15.910
# 10884  19-12-2012 22:00       4        0           1        1  13.94  17.425
# 10885  19-12-2012 23:00       4        0           1        1  13.12  16.665
#
#        humidity  windspeed  casual  registered  count
# 0            81     0.0000       3          13     16
# 1            80     0.0000       8          32     40
# 2            80     0.0000       5          27     32
# 3            75     0.0000       3          10     13
# 4            75     0.0000       0           1      1
# ...         ...        ...     ...         ...    ...
# 10881        50    26.0027       7         329    336
# 10882        57    15.0013      10         231    241
# 10883        61    15.0013       4         164    168
# 10884        61     6.0032      12         117    129
# 10885        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %% [markdown]
# printing number of rows and columns

# %%
data.shape
# Out:
# (10886, 12)

# %% [markdown]
# printing data info

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB
# None

# %% [markdown]
# Dealing with Null Values

# %%
data.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %% [markdown]
# printing columns

# %%
print(data.columns)
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %% [markdown]
# First 5 rows

# %%
print(data.head())
# Out:
#            datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  01-01-2011 00:00       1        0           0        1  9.84  14.395
# 1  01-01-2011 01:00       1        0           0        1  9.02  13.635
# 2  01-01-2011 02:00       1        0           0        1  9.02  13.635
# 3  01-01-2011 03:00       1        0           0        1  9.84  14.395
# 4  01-01-2011 04:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# Performing Exploratory Data Analysis

# %%
data.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %% [markdown]
# Changing data (string) to date format for easy extraction of month,date,year,hour,minute

# %%
data['datetime'] = pd.to_datetime(data['datetime'], format='%d-%m-%Y %H:%M', errors='coerce')

# %%
data['hour'] = data['datetime'].dt.hour
data['day'] = data['datetime'].dt.day
data['month'] = data['datetime'].dt.month
data['year'] = data['datetime'].dt.year
data['weekday'] = data['datetime'].dt.weekday
data['is_weekend'] = data['weekday'].apply(lambda x: 1 if x >= 5 else 0)

# %%
data.shape
# Out:
# (10886, 18)

# %% [markdown]
# Visualizing the Demand using multiple variables

# %% [markdown]
# Demand per day of the week

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=data, x='weekday', y='count', palette='rainbow')
plt.xticks(ticks=range(7), labels=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.show()
# Out:
# /tmp/ipykernel_1520/1497216664.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='weekday', y='count', palette='rainbow')

# %% [markdown]
# Demand per month

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=data, x='month', y = 'count', palette = 'rainbow');
# Out:
# /tmp/ipykernel_1520/3859061535.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='month', y = 'count', palette = 'rainbow');

# %% [markdown]
# Demand per hour

# %%
plt.figure(figsize=(12,6))
sns.barplot(data = data, x = 'hour', y = 'count', palette = 'rainbow');
# Out:
# /tmp/ipykernel_1520/1608152374.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = data, x = 'hour', y = 'count', palette = 'rainbow');

# %% [markdown]
# Demand per season

# %%
plt.figure(figsize = (8,4))
sns.barplot(data = data, x = 'season', y = 'count', palette = 'rainbow');
# Out:
# /tmp/ipykernel_1520/2853728546.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = data, x = 'season', y = 'count', palette = 'rainbow');

# %% [markdown]
# Demand as per holidays

# %%
plt.figure(figsize=(6,6))
sns.barplot(data = data, x = 'holiday', y = 'count', palette = 'rainbow');
# Out:
# /tmp/ipykernel_1520/1367454579.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = data, x = 'holiday', y = 'count', palette = 'rainbow');

# %% [markdown]
# Correlation Matrix of Bike Sharing Features

# %%
corrdata = data[['season','weather', 'holiday', 'workingday', 'is_weekend']]
corrmat = corrdata.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corrmat, annot=True, cmap='winter');
plt.title('Correlation Matrix of Bike Sharing Features')
plt.show()

# %% [markdown]
# Feature Engineering

# %%
data['humidity_windspeed_ratio'] = data['humidity'] / (data['windspeed'] + 1)
data['temp_atemp_diff'] = data['temp'] - data['atemp']

# %%
data['prev_hour_count'] = data['count'].shift(1).fillna(method='bfill')
# Out:
# /tmp/ipykernel_1520/2022162451.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['prev_hour_count'] = data['count'].shift(1).fillna(method='bfill')

# %%
data.shape
# Out:
# (10886, 21)

# %% [markdown]
# Correlation Matrix of All Features

# %%
corr_matrix = data.corr()
plt.figure(figsize=(20, 15))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix of All Features")
plt.show()

# %% [markdown]
# Scaling Continuous Variables

# %%
scaler = MinMaxScaler()
data[['temp', 'atemp', 'humidity', 'windspeed', 'humidity_windspeed_ratio']] = scaler.fit_transform(
    data[['temp', 'atemp', 'humidity', 'windspeed', 'humidity_windspeed_ratio']]
)

# %% [markdown]
# Log Transformation of Target Variable

# %%
data['count'] = np.log1p(data['count'])

# %%
X = data.drop(columns=['datetime', 'count', 'casual', 'registered'])
y = data['count']
X
# Out:
#        season  holiday  workingday  weather      temp     atemp  humidity  \
# 0           1        0           0        1  0.224490  0.305068      0.81
# 1           1        0           0        1  0.204082  0.288064      0.80
# 2           1        0           0        1  0.204082  0.288064      0.80
# 3           1        0           0        1  0.224490  0.305068      0.75
# 4           1        0           0        1  0.224490  0.305068      0.75
# ...       ...      ...         ...      ...       ...       ...       ...
# 10881       4        0           1        1  0.367347  0.423649      0.50
# 10882       4        0           1        1  0.346939  0.372860      0.57
# 10883       4        0           1        1  0.326531  0.338964      0.61
# 10884       4        0           1        1  0.326531  0.372860      0.61
# 10885       4        0           1        1  0.306122  0.355856      0.66
#
#        windspeed  hour  day  month  year  weekday  is_weekend  \
# 0       0.000000     0    1      1  2011        5           1
# 1       0.000000     1    1      1  2011        5           1
# 2       0.000000     2    1      1  2011        5           1
# 3       0.000000     3    1      1  2011        5           1
# 4       0.000000     4    1      1  2011        5           1
# ...          ...   ...  ...    ...   ...      ...         ...
# 10881   0.456213    19   19     12  2012        2           0
# 10882   0.263195    20   19     12  2012        2           0
# 10883   0.263195    21   19     12  2012        2           0
# 10884   0.105325    22   19     12  2012        2           0
# 10885   0.157870    23   19     12  2012        2           0
#
#        humidity_windspeed_ratio  temp_atemp_diff  prev_hour_count
# 0                      0.810000           -4.555             16.0
# 1                      0.800000           -4.615             16.0
# 2                      0.800000           -4.615             40.0
# 3                      0.750000           -4.555             32.0
# 4                      0.750000           -4.555             13.0
# ...                         ...              ...              ...
# 10881                  0.018517           -4.115            569.0
# 10882                  0.035622           -2.665            336.0
# 10883                  0.038122           -1.970            241.0
# 10884                  0.087103           -3.485            168.0
# 10885                  0.066013           -3.545            129.0
#
# [10886 rows x 17 columns]

# %% [markdown]
# Split dataset into training and testing sets (80% train, 20% test)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# **Random Forest Algorithm**

# %% [markdown]
# Train Initial Random Forest Model

# %%
rf_model = RandomForestRegressor(n_estimators=8, max_depth=3, random_state=1)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# %% [markdown]
# Evaluate Model Performance

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# %%
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae}')
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error (MSE): {mse}')
rmse = np.sqrt(mse)

r2 = r2_score(y_test, y_pred)

print(f'Optimized Random Forest RMSE: {rmse}')
print(f'Optimized Random Forest Accuracy (R² Score): {r2:.4f}')
# Out:
# Mean Absolute Error (MAE): 0.4253899750203931
# Mean Squared Error (MSE): 0.3028180707446978
# Optimized Random Forest RMSE: 0.5502890792526214
# Optimized Random Forest Accuracy (R² Score): 0.8514

# %% [markdown]
# **Using Linear Regression**

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)
X_train_poly, X_test_poly, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=1)
model_poly = LinearRegression()
model_poly.fit(X_train_poly, y_train)
y_pred_poly = model_poly.predict(X_test_poly)
accuracy_poly = model_poly.score(X_test_poly, y_test)
print(f"Accuracy with Polynomial Features: {accuracy_poly}")
# Out:
# Accuracy with Polynomial Features: 0.792363394631813

# %% [markdown]
# Using SVM Algorithm

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
svm_model = SVR(kernel='rbf', C=10, gamma='scale')
svm_model.fit(X_train_scaled, y_train)
y_pred_svm = svm_model.predict(X_test_scaled)
r2_svm = r2_score(y_test, y_pred_svm)
print(f"SVM Accuracy (R^2 Score): {r2_svm}")
rmse_svm = np.sqrt(mean_squared_error(y_test, y_pred_svm))
print(f"SVM RMSE: {rmse_svm}")
# Out:
# SVM Accuracy (R^2 Score): 0.854683762945378
# SVM RMSE: 0.5441087763108614

# %%
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
X, y = make_blobs(n_samples=100, centers=2, random_state=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
svm = SVC(kernel='linear', C=1)
svm.fit(X_scaled, y)
plt.figure(figsize=(8, 6))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = svm.decision_function(xy).reshape(XX.shape)
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
ax.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')

plt.title('SVM Decision Boundary')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
